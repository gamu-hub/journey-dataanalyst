# %%
for i in range(1-6):
    print(i)

# %%
for i in range(0, 11, 2):
    print(i)

# %%
for i in range(10):
    if i == 5:
        break

    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
while True:
    print("Hello")

# %%
# Ask the user for a number and print:

# Example:

# 5 x 1 = 5
# 5 x 2 = 10

number = int(input("Enter a number: "))

for i in range(1, 11):
    print(number, "x", i, "=", number * i)
# Out:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %%
# Python:

# evaluates each thing
# converts to text
# joins with spaces
# displays result

# That’s the core idea.
