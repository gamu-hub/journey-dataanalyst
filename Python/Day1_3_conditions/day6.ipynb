# %%
def say_hello():
    print("Hello!")

say_hello()

# %%
def say_welcome():
    print("Welcome to HOPE esports")
say_welcome()

# %%
def I_love():
    print("I love foodS!")
I_love()

# %%
def greet(name):
    print("Hello", name)
greet("Lootpu")
greet("Niangboi")

# %%
def greet(name):
    print("Hello", name)

greet("Lootpu")
greet("Niangboi")

# %%
# Part 3 — Functions With Return

# SUPER IMPORTANT TOPIC.

def add (a, b):
    return a + b
result = add(5,3)
print(result)
# Out:
# 8

# %%
def bmi(weight, height):
    return weight / (height * height)

result = bmi(59, 1.55)
print("Your BMI is"), result
# Out:
# Your BMI is
# (None, 24.55775234131113)
