# %% [markdown]
# 1. Learn These Topics
# A. Common Python Errors
# # NameError
# print(name)
# # ValueError
# age = int("abc")
# # ZeroDivisionError
# result = 10 / 0
# # FileNotFoundError
# with open("missing.txt"):
#     pass

# %% [markdown]
# B. Try & Except
# try:
#     age = int(input("Enter age: "))
#     print(age)
# except:
#     print("Invalid input")

# %% [markdown]
# try:
#     number = int(input("Enter number: "))
#     result = 100 / number
#     print(result)
#
# except ValueError:
#     print("Please enter a number")
#
# except ZeroDivisionError:
#     print("Cannot divide by zero")

# %%
try:
    number = int(input("Enter number:"))
    result = 100 / number
    print(result)

except ValueError:
    print("Please enter a number")
    
except ZeroDivisionError:
    print("Cannot divide by zero")

# %% [markdown]
# D. Else and Finally
# try:
#     num = int(input("Number: "))
# except ValueError:
#     print("Invalid")
# else:
#     print("Success")
# finally:
#     print("Program finished")

# %%
try:
    num = int(input("Number: "))
except ValueError:
    print("Invalid")
else:
    print("Success")
finally:
    print("Program finished")
# Out:
# Success
# Program finished
