# %%
import csv
with open("studetns.csv", "r") as file:
    reader = csv.reader(file)

    for row in reader:
        print(row)
# Out:
# ['name', 'age', 'grade']
# ['John', '20', 'A']
# ['Anna', '21', 'B']
# ['Mike', '19', 'A']

# %%
import csv
with open("students.csv", "w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["name", "age", "grade"])
    writer.writerow(["John", 20, "A"])

# %%
import csv
with open("students.csv", "r") as file:
    reader = csv.reader(file)
    next(reader)
    for row in reader:
        print(row)
# Out:
# ['John', '20', 'A']

# %%
import csv
with open("people.csv", "r") as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 import csv
# ----> 2 with open("people.csv", "r") as file:
#       3     reader = csv.reader(file)
#       4     for row in reader:
#       5         print(row)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'people.csv'

# %%
import csv
with open("new.csv", "w", newline= "") as file:
    writer = csv.writer(file)

    writer.writerow(["name", "city"])
    writer.writerow(["Mike", "Rome"])

# %%
import csv
with open("products.csv", "w", newline="") as file:
    writer = csv.writer(file)
    
    writer.writerow(["products", "price"])
    writer.writerow(["Phone", 500])
    writer.writerow(["Laptop", 1200])
    writer.writerow(["Mouse", 500])

# %%
import csv
with open("products.csv", "r",) as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['products', 'price']
# ['Phone', '500']
# ['Laptop', '1200']
# ['Mouse', '500']

# %%
import csv
with open("products.csv", "r") as file:
    reader = csv.reader(file)
    next(reader)
    for row in reader:
        print(row[0])
# Out:
# Phone
# Laptop
# Mouse

# %%
import csv
with open("products.csv", "r") as file:
    reader = csv.reader(file)
    next(reader)
    for row in reader:
        print(row[0], "cost", row [1])
# Out:
# Phone cost 500
# Laptop cost 1200
# Mouse cost 500
