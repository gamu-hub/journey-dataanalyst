# %%
student = {
    "name": "John",
    "age": 22,
    "course": "Data Analytics"
}
print(student["name"])
print(student["age"])
# Out:
# John
# 22

# %%
student = {
    "name": "John",
    "age": 22
}
print(student["name"])
print(student["age"])
# Out:
# John
# 22

# %%
student = {
    "name": "John"
}

student["age"] = 22
student["city"] = "London"

print(student)
# Out:
# {'name': 'John', 'age': 22, 'city': 'London'}

# %%
student = {
    "name": "John",
    "age": 22
}

student["age"] = 25
print(student)
# Out:
# {'name': 'John', 'age': 25}

# %%
student = {
    "name": "John",
    "age": 22

}
del student["age"]
print(student)
# Out:
# {'name': 'John'}

# %%
student = {
    "name": "Niang",
    "age": 30
}
del student["age"]
print(student)
# Out:
# {'name': 'Niang'}

# %%
student = {
    "name": "John",
    "age": 22,
    "city": "London"
}

for key in student:
    print(key)
for value in student.values():
    print(value)
# Out:
# name
# age
# city
# John
# 22
# London

# %%
student= {
    "name": "Niang",
    "class": "Python",
    "age": 30
    
}

for value in student.values():
    print(value)
# Out:
# Niang
# Python
# 30

# %%
people = {
    "name": "Niang",
    "country": "Israel",
    "address": "Nakhalim"
}

for key, value in people.items():
    print(key, value)
# Out:
# name Niang
# country Israel
# address Nakhalim

# %%
employees = {
    "emp1": {
        "name": "John",
        "salary": 3000
    },
    
    "emp2": {
        "name": "Sarah",
        "salary": 4500
    }
}

print(employees["emp1"]["name"])
print(employees["emp2"]["salary"])
# Out:
# John
# 4500

# %%
school = {
    "student1": {
        "name": "Mike",
        "age": "A"
    },
    "student2": {
        "name": "Anna",
        "grade": "B"
    }
}

for student, info in school.items():
    print(student)
    for key, value in info.items():
        print(key, value)
    print()
# Out:
# student1
# name Mike
# age A
#
# student2
# name Anna
# grade B

# %%
text = "apple banana apple orange banana apple"
words = text.split()
count = {}

for word in words:
    if word in count:
        count[word] += 1
    else:
        count[word] = 1
print(count)
# Out:
# {'apple': 3, 'banana': 2, 'orange': 1}

# %%
text = "apple banana apple orange banana apple"

words = text.split()

count = {}

for word in words:
    if word in count:
        count[word] += 1
    else:
        count[word] = 1
print(count)
# Out:
# {'apple': 3, 'banana': 2, 'orange': 1}

# %%
numbers = [1,2,2,3,1,1,4,5,2]
frequency = {}

for num in numbers:
    if num in frequency:
        frequency[num] += 1
    else:
        frequency[num] = 1
print(frequency)
# Out:
# {1: 3, 2: 3, 3: 1, 4: 1, 5: 1}

# %%
sales = [
    {"product": "Phone", "price": 500},
    {"product": "Laptop", "price": 1200},
    {"product": "Accessories", "price": 500}

]

total = 0

for item in sales:
    total += item["price"]
print("Total sales:", total)
print(len(sales))
# Out:
# Total sales: 2200
# 3

# %%
sales = [
    {"product": "Phone", "price": 500},
    {"product": "Laptop", "price": 1200},
    {"product": "Accessories", "price": 500}
]

total = 0

for item in sales:
    total += item["price"]
print("Total sales:", total)
# Out:
# Total sales: 2200

# %%
car = {
    "Brand": "Toyota",
    "Model" : "Corolla",
    "Year" : "2026"
}
print(car["Brand"])
print(car["Model"])
print(car["Year"])
# Out:
# Toyota
# Corolla
# 2026

# %%
student = {
    "name": "Niang",
    "age": 33
}
student ["age"] = 32
student["city"] = "Nakhalim"
student["course"] = "Python"
print(student)
# Out:
# {'name': 'Niang', 'age': 32, 'city': 'Nakhalim', 'course': 'Python'}

# %%
student = {
    "name": "John",
    "age": 25,
    "city": "London"
}
for key, value in student.items():
    print(key, value)
# Out:
# name John
# age 25
# city London

# %%
student = {
    "name": "John",
    "age": 25,
    "city": "London"
}

for key, value in student.items():
    print(key, value)
# Out:
# name John
# age 25
# city London

# %%
employees ={
    "emp1": {
        "name": "Mike",
        "salary": 4000
    },

    "emp2": {
        "name": "Anna",
        "salary": 5000
    }
}
print(employees["emp1"]["name"])
print(employees["emp2"]["salary"])
# Out:
# Mike
# 5000

# %%
text = "cat dog cat bird dog cat"
words = text.split()
count = {}
for word in words:
    if word in count:
        count[word] += 1
    else:
        count[word] = 1
print(count)
# Out:
# {'cat': 3, 'dog': 2, 'bird': 1}

# %%
numbers = [1,1,2,3,2,1,4,5,4]
frequency = {}

for num in numbers:
    if num in frequency:
        frequency[num] += 1
    else:
        frequency[num] = 1
print(frequency)
# Out:
# {1: 3, 2: 2, 3: 1, 4: 2, 5: 1}

# %%
grades = {
    "John": 90,
    "Sarah": 85,
    "Mike": 78
}

for key, value in grades.items():
    print(key, value)

total = 0

for grade in grades.values():
    total += grade
average = total/len(grades)
print(average)
# Out:
# John 90
# Sarah 85
# Mike 78
# 84.33333333333333

# %%
grades = {
    "John": 90,
    "Sarah": 85,
    "Mike": 78
}

for key, value in grades.items():
    print(key, value)

total = 0
for grade in grades.values():
    total += grade
average = total/len(grades)
print(average)
# Out:
# John 90
# Sarah 85
# Mike 78
# 84.33333333333333
