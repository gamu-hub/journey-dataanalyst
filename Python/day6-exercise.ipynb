# %%
# exercise 1

def say_hello():
    print("Hello!")

say_hello()

def say_welcome():
    print("Welcome to HOPE esports")
say_welcome()

# %%
# Exercise 2

# Create:

# def team_player(player):

# Output example:

# team_player("Alex")



def team_player(player):
    print(player, "joined HOPE esports")
team_player("Alex")
# Out:
# Alex joined HOPE esports

# %%
# Exercise 3

# Create a function:

# def multiply(a, b):

# Return the multiplication result.

# Then print the result outside the function.

def multiply(a, b):
    return a * b
result = multiply(4,5)
print(result)
# Out:
# 20
