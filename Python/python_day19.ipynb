# %%
numbers = {1, 2, 3, 4}
print(numbers)
# Out:
# {1, 2, 3, 4}

# %%
emails = ["a@gmail.com", "b@gmail.com", "a@gmail.com"]
unique_emails = set(emails)
print(unique_emails)
# Out:
# {'a@gmail.com', 'b@gmail.com'}

# %%
numbers = [1,2,2,3,4,5,6,4,5,6,4,3,2,1,2,4,3,2,1]
unique_numbers = set(numbers)
print(unique_numbers)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
colors = {"red", "blue"}

colors.add("green")

print(colors)
# Out:
# {'red', 'green', 'blue'}

# %%
colors = {"red", "blue", "pink"}
colors.remove("pink")
colors.discard("yellow")
print(colors)
# Out:
# {'red', 'blue'}

# %%
a = {1, 2, 3}
b = {3, 4, 5}

print(a | b)
# Out:
# {1, 2, 3, 4, 5}

# %%
a = {1, 2, 3}
b = {3, 4, 5}

print(a & b)
# Out:
# {3}

# %%
a = {1, 2, 3}
b = {3, 4, 5}

print(a - b)
# Out:
# {1, 2}

# %%
person = ("John", 25, "USA")
print(person[1])
# Out:
# 25

# %%
person = ("John", 25)
name, age = person

print(name)
print(age)
# Out:
# John
# 25

# %%
{ 
    "name": "John",
    "age": 25,
    "city": "London"
}
# Out:
# {'name': 'John', 'age': 25, 'city': 'London'}

# %%
import json
person = {
    "name": "John",
    "age": 25,
    "city": "Nakhalim"
}

json_data = json.dumps(person)
print(json_data)
# Out:
# {"name": "John", "age": 25, "city": "Nakhalim"}

# %%
import json
data = '{"name": "John", "age": 25}'

python_data = json.loads(data)

print(python_data)
# Out:
# {'name': 'John', 'age': 25}

# %%
numbers = {1, 2, 2, 3, 4, 4, 5}
print(numbers)
# Out:
# {1, 2, 3, 4, 5}

# %%
fruits = {"apple", "banana"}
fruits.add("orange")
print(fruits)
# Out:
# {'orange', 'apple', 'banana'}

# %%
a = {1, 2, 3, 4}
b = {3, 4, 5, 6}

print(a & b)
# Out:
# {3, 4}

# %%
student = ("Sarah", 22)
name, age = student

print(name)
print(age)
# Out:
# Sarah
# 22

# %%
import json
person = {
    "name": "Mike",
    "age": 30
}

json_data = json.dumps(person)
print(json_data)
# Out:
# {"name": "Mike", "age": 30}

# %%
import json
person = {
    "name": "Niangboi",
    "age": 33,
    "city": "Nakhalim"
}

json_data = json.dumps(person)
print(json_data)
# Out:
# {"name": "Niangboi", "age": 33, "city": "Nakhalim"}
