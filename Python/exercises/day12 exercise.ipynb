# %%
try:
    age = int(input("Enter age:"))
    print(age)
except:
    print("Invalid input")
# Out:
# Invalid input

# %% [markdown]
# 2. Exercises
# Exercise 1
#
# Ask for a number.
#
# If the user enters text:
#
# Please enter a valid number
#
# instead of crashing.

# %%
try:
    number = int(input("Enter a number: "))
    print("Saved!")
except ValueError:
    print("Please enter a valid number")
# Out:
# Please enter a valid number

# %% [markdown]
# Exercise 2:
#
# Task
#
# Ask the user for two numbers.
#
# Divide the first number by the second number.
#
# Requirements:
#
# If the user enters text instead of a number → show an error message.
# If the second number is 0 → show a message instead of crashing.

# %%
try:
    num1 = int(input("Enter first number: "))
    num2 = int(input("Enter second number: "))
    result = 100 / number
    print(result)
except ValueError:
    print("Please enter a number")

except ZeroDivisionError:
    print("Cannot divide by zero")
# Out:
# 50.0

# %% [markdown]
# Exercise 3 — File Handling Errors
#
# Task:
#
# Ask the user for a filename.
#
# Try to open it.
#
# If the file exists, print:
#
# File opened successfully
#
# If the file does not exist, print:
#
# File not found

# %%
filename = input("Enter a filename: ")
try:
    with open(filename, "r"):
        print("File opened successful")

except FileNotFoundError:
    print("File not found")
# Out:
# File opened successful

# %% [markdown]
# Exercise 4
#
# Keep asking for a number until the user enters a valid integer.
#
# Example:
#
# Enter number: abc
# Invalid
#
# Enter number: hello
# Invalid
#
# Enter number: 25
# Thank you

# %%
while True:
    try:
        number = int(input("Enter a number: "))
        print("Thank you")
        break
    except ValueError:
        print("Invalid")
# Out:
# Invalid
# Invalid
# Invalid
# Invalid
# Invalid
# Invalid
# Invalid
# Invalid
# Invalid
# Thank you
