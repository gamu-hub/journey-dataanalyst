# %% [markdown]
# Mini Challenge 1
#
# Without copying:
# Create a list of 5 countries and:
#
# print the first one
# print the last one
# print total number of countries

# %%
countries = ["India", "Israel", "America", "England", "Nepal"]
print(countries[0])
print(countries[4])
print(len(countries))

# %% [markdown]
# Mini Challenge 2
#
# Create a list of favorite foods.
#
# Loop through them and print:
#
# I like pizza
# I like burger

# %%
fav_foods = ["Pizza", "Egg", "Noodles"]
for food in fav_foods:
    print("I like", food)
# Out:
# I like Pizza
# I like Egg
# I like Noodles

# %% [markdown]
# Part 3 — Logic Practice (30 min)
#
# Now we stop relying fully on examples.
#
# Exercise 1
# numbers = [5, 10, 15, 20]
#
# Print all numbers bigger than 10.

# %%
numbers = [5, 10, 15, 20]
for num in numbers:
    if num >= 10:
        print(num)
# Out:
# 10
# 15
# 20

# %% [markdown]
# Exercise 2
#
# Count total items in a list WITHOUT using len().
#
# Hint:
#
# create counter variable
# loop through list
# increase counter

# %%
numbers = [10, 20, 30, 40, 50]
counter = 0
for num in numbers:
    counter = counter + 1
print(counter)
# Out:
# 5

# %%
numbers = [10,20,30,40,50]
total = 0
for num in numbers:
    total += 1
print(total)
# Out:
# 5

# %% [markdown]
# Exercise 3
#
# Find the total sum manually:
#
# numbers = [1, 2, 3, 4, 5]
#
# Expected output:
#
# 15
#
# Hint:
# This is VERY similar to your counter exercise.
# Difference:
#
# before → adding 1
# now → add the actual number (num) each loop
#
# Think in English first:
#
# “Start total at 0.”
# “Loop through every number.”
# “Add each number into total.”

# %%
numbers = [1,2,3,4,5]
total = 0
for num in numbers:
    total += num
print(total)
# Out:
# 15

# %% [markdown]
# Final Challenge (Important)
#
# Now try this one carefully without looking too much at previous examples.
#
# Print ONLY even numbers
#
# Example list:
#
# numbers = [1,2,3,4,5,6,7,8]
#
# Expected output:
#
# 2
# 4
# 6
# 8
#
# Hint:
# Use:
#
# % 2
#
# Think in English:
#
# “Loop through every number.”
# “Check if the number is even.”
# “If yes, print it.”

# %%
numbers = [1,2,3,4,5,6,7,8]
for num in numbers:
    if num %2 == 0:
        print(num)
# Out:
# 2
# 4
# 6
# 8

# %% [markdown]
# One Small Challenge Before Ending Today
#
# Try this by yourself:
#
# numbers = [3, 7, 10, 15, 20, 22]
#
# Print ONLY numbers greater than 10.
#
# Expected:
#
# 15
# 20
# 22
#
# No hints first.
# Try solving from your own understanding.

# %%
numbers = [3,7, 10, 15, 20, 22]
for num in numbers:
    if num > 10:
        print(num)
# Out:
# 10
# 15
# 20
# 22
