# %%
# Out:
# Apple
# Banana
# Orange

# %%
fruit = input("Favourite fruit:")

with open("fruits.txt", "a") as file:
    file.write(fruit + "\n")

# %%
with open("fruits.txt", "r") as file:
   content = file.read()
   
print(content)
# Out:
# Apple
# Banana
# Orange

# %%
count = 0
with open("fruits.txt", "r") as file:
    for line in file:
        count += 1
print(count)
# Out:
# 3

# %%
search = input("Search fuits:")

with open("fruits.txt", "r") as file:
    for line in file:
        if search == line.strip():
            print("Found!")
# Out:
# Found!

# %% [markdown]
# Exercise 1
#
# Create a program that saves favorite movies into movies.txt.

# %%
fav_movies = input()
with open ("movies.txt", "a") as file:
    file.write (fav_movies + "\n")
print("Movies saved!")
# Out:
# Movies saved!

# %% [markdown]
# Exercise 2: Read all movies and print them.
#
# Try writing it yourself first.
#
# Hint
#
# You need:
#
# Open the file in "r" mode.
# Read the contents.
# Print the contents.

# %%
with open("movies.txt", "r") as file:
    for line in file:
        print(line.strip())
# Out:
# Chhichore
# 3 idiots
# Navy Seals

# %% [markdown]
# Exercise 3: Count how many movies are saved
#
# Try writing the code yourself first.

# %%
count = 0

with open("movies.txt", "r") as file:
    for line in file:
        count = count +1
print(count)
# Out:
# 4

# %% [markdown]
# Exercise 4 Goal
#
# Ask the user for a movie name.
#
# Check whether that movie exists in movies.txt.

# %%
search = input("Search movie:")
found = False

with open("movies.txt", "r") as file:
    for line in file:
        if search == line.strip():
            found = True
if found:
    print("Found!")
else:
    print("Not Found")
# Out:
# Found!
