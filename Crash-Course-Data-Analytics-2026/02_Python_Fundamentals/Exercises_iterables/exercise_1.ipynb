# %% [markdown]
# We’ll use a string and apply several string methods to see how they change the text. Follow the steps below, run the code, and observe the results!
#
# text = "Python is Fun!"
# 1. Convert the entire string to uppercase
#
# 2. Make the first letter upper case
#
# 3. Make the first letter of each word upper case
#
# 4. Find the index of "F". What happens if you use lower case in the method?
#
# 5. Find a substring

# %%
text = "Python is Fun!"

print(text.upper())

text = "Python is Fun!"
print(text.capitalize())


text = "Python is Fun!"
print(text.title())


text = "Python is Fun!"
print(text.index("F"))

print(text.index("f")) # wrong since we don't have small f

text = "Python is Fun!"
print(text.find("Fun"))
# Out:
# PYTHON IS FUN!
# Python is fun!
# Python Is Fun!
# 10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 16
#      12
#      13 text = "Python is Fun!"
#      14 print(text.index("F"))
#      15
# ---> 16 print(text.index("f")) # wrong since we don't have small f
#      17
#      18 text = "Python is Fun!"
#      19 print(text.find("Fun"))
#
# ValueError: substring not found
