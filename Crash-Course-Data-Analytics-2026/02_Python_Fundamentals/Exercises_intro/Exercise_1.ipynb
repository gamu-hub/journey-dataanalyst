# %%
# This is my first exercises (same to the question to write a comment)
first = "Hello World"

# %%
print("I AM A COMPUTER")
# Out:
# I AM A COMPUTER

# %%
if 1 < 2 and 4 > 2:
    print("Math is fun")
# Out:
# Math is fun

# %%
variable_name = None

# %%
True and False
# Out:
# False

# %%
result = "First Position"
print(len(result))
# Out:
# 14

# %%
#converting "i am shouting" to uppercase

text = "i am shouting"
text.upper()
# Out:
# 'I AM SHOUTING'

# %%
number = int("1000")
print(number)
# Out:
# 1000

# %%
number = 4
print(str(4)+ "real")
# Out:
# 4real

# %%
print(3 * "cool")
# Out:
# coolcoolcool

# %%
print(1/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 print(1/0)
#
# ZeroDivisionError: division by zero

# %%
# Determine the type of []

# this means empty list

# %%
name = input("What is your name")

# %%
number = int(input("Enter your number"))

if number < 0:
    print("That number is less than 0")
elif number > 0:
    print("That number is greater than 0")
else:
    print("You pick 0!")
# Out:
# You pick 0!

# %%
name = "apple"
name.index("l")
# Out:
# 3

# %%
"y" in "xylophone"
# Out:
# True

# %%
word = "my_string"
word.islower()
# Out:
# True
