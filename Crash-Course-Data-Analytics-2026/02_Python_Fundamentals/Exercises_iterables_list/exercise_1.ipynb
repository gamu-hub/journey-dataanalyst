# %%
fruits = ["apple", "banana", "cherry", "date", "elderberry"]

print(fruits[0])
print(fruits[2])
print(fruits[6]) # list index out of range
#4 changing the second fruit bannan to blueberry

fruits[1] = "blueberry"
print(fruits)
# Out:
# apple
# cherry
# ['apple', 'blueberry', 'cherry', 'date', 'elderberry']
