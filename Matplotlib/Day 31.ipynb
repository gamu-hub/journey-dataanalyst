# %% [markdown]
# Step 1: Import Matplotlib
# import matplotlib.pyplot as plt

# %% [markdown]
# Step 2: Create a Line Chart
# plt.plot(df["Month"], df["Sales"])
# plt.show()
#
# this creates your first graph

# %% [markdown]
# Step 3: Add a Title
# plt.plot(df["Month"], df["Sales"])
#
# plt.title("Monthly Sales")
#
# plt.show()

# %% [markdown]
# Step 4: Label the Axes
# plt.plot(df["Month"], df["Sales"])
#
# plt.title("Monthly Sales")
# plt.xlabel("Month")
# plt.ylabel("Sales")
#
# plt.show()
#
# Markers make each data point easier to see

# %% [markdown]
# Step 6: Add Grid
# plt.plot(df["Month"], df["Sales"], marker="o")
#
# plt.title("Monthly Sales")
# plt.xlabel("Month")
# plt.ylabel("Sales")
#
# plt.grid(True)
#
# plt.show()

# %% [markdown]
# Step 7: Change Line Style
# plt.plot(df["Month"], df["Sales"],
#          marker="o",
#          linestyle="--")
#
# plt.show()
#
# Other line styles:
#
# "-"   Solid
# "--"  Dashed
# ":"   Dotted
# "-."  Dash-dot

# %% [markdown]
# Step 5: Add Markers
# plt.plot(df["Month"], df["Sales"], marker="o")
#
# plt.title("Monthly Sales")
# plt.xlabel("Month")
# plt.ylabel("Sales")
#
# plt.show()

# %% [markdown]
# | Function                          | Purpose                 |
# | --------------------------------- | ----------------------- |
# | `import matplotlib.pyplot as plt` | Import plotting library |
# | `plt.plot()`                      | Create a line chart     |
# | `plt.title()`                     | Add chart title         |
# | `plt.xlabel()`                    | Label x-axis            |
# | `plt.ylabel()`                    | Label y-axis            |
# | `plt.grid()`                      | Show grid lines         |
# | `plt.show()`                      | Display the chart       |

# %% [markdown]
# Step 8: Complete Chart

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    "Month": ["Jan", "Feb", "Mar", "Apr", "May", "Jun"],
    "Sales": [1200, 1500, 1700, 1600, 2100, 2500]
}

df = pd.DataFrame(data)


plt.plot(df["Month"], df["Sales"],
         marker="o",
         linestyle="--")

plt.title("Monthly Sales")

plt.xlabel("Month")

plt.ylabel("Sales")

plt.grid(True)

plt.show()

# %% [markdown]
# 🏋️ Practice Exercises

# %% [markdown]
# Exercise 1
#
# Create a line chart using:
#
# Months = ["Jan","Feb","Mar","Apr"]
# Profit = [100,150,130,200]

# %%
import matplotlib.pyplot as plt

Months = ["Jan", "Feb", "Mar", "Apr"]
Profit = [100, 150, 130, 200]

plt.plot(Months, Profit, marker = "o")
plt.title("Monthly Profit")
plt.xlabel("Month")
plt.ylabel("Profit")
plt.grid(True)
plt.show()

# %% [markdown]
# Exercise 2
#
# Use this data:
#
# Days = ["Mon","Tue","Wed","Thu","Fri"]
# Visitors = [55,70,65,90,110]
#
# Create a chart with:
#
# title
# x label
# y label
# markers
# grid

# %%
import matplotlib.pyplot as plt

Days = ["Mon", "Tue", "Wed", "Thu", "Fri"]
Visitors = [55, 70, 65, 90, 110]


plt.plot(df["Days"], df["Visitors"], marker = "o")
plt.title("Daily Visitors")
plt.xlabel("Days")
plt.ylabel("Visitors")
plt.grid(True)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Lootpu\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...
